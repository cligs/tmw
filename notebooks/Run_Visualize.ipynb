# %% [markdown]
# # Run Visualize
#
# (author: uhk, based on run_visualize.py by cs, created on: October 2017)
#
# This notebook is for calling functions from TMW's visualize module.
#
# General advice on how to use the notebook:
#
# * Run the code blocks one after the other. The blocks "Imports" and "General Settings" have to be run first.
# * Each visualization block, e.g. plot words-in-topics-treemap, can be run separately.
# * Some settings need to be changed, e.g. your working directory, number of topics, parameters, ... the comments say "set..." where this is the case. No other changes have to be made to the code.

# %% [markdown]
# ## Imports

# %%
from os.path import join
from os.path import abspath
import importlib
import sys

# %%
"""
set the path to the directory where you stored TMW
"""
tmw_path = "/home/ulrike/Git/tmw"

# %%
sys.path.append(abspath(join(tmw_path, "scripts_verona")))
"""
this shows your path settings
"""
print(sys.path)
# Out:
# ['', '/usr/lib/python35.zip', '/usr/lib/python3.5', '/usr/lib/python3.5/plat-x86_64-linux-gnu', '/usr/lib/python3.5/lib-dynload', '/home/ulrike/.local/lib/python3.5/site-packages', '/usr/local/lib/python3.5/dist-packages', '/usr/local/lib/python3.5/dist-packages/wikiextractor-2.69-py3.5.egg', '/usr/lib/python3/dist-packages', '/home/ulrike/.local/lib/python3.5/site-packages/IPython/extensions', '/home/ulrike/.ipython', '/home/ulrike/Git/tmw/scripts', '/home/ulrike/Git/tmw/scripts_verona']

# %%
import visualize_verona

importlib.reload(visualize_verona)
# Out:
# <module 'visualize_verona' from '/home/ulrike/Git/tmw/scripts_verona/visualize_verona.py'>

# %% [markdown]
# ## General settings

# %%
"""
set the working directory
- a folder which contains the metadata file, the corpus folder, etc.
- the topic modeling output will be stored in new subfolders inside the working directory
"""
wdir = "/home/ulrike/Dokumente/GS/Veranstaltungen/2017_Verona/exercises_English"

"""
set the model folder name
"""
model_folder = "mallet_model"

"""
set the file name of the MALLET --topic-word-weights option, which is usually "word-weights"
(without the ending .txt)
"""
word_weights = "word-weights"


"""
set the aggregate folder name
"""
aggregates_folder = "8_aggregates"

"""
set the output folder name for visualizations
"""
out_folder = "9_visuals"

# %%
out_dir = join(wdir, out_folder)

# %%
"""
set the parameters as they were used in the topic modeling
- these settings will be used for output file names
"""
NumTopics = 30
NumIterations = 500
OptimizeIntervals = 50
TopTopics = 20

# %%
param_settings = str(NumTopics) + "tp-" + str(NumIterations) + "it-" + str(OptimizeIntervals) + "in-" + str(TopTopics) + "tt"

# %% [markdown]
# ## make_wordle_from_mallet

# %%
"""
create a wordle for each topic from MALLET
"""

"""
set the number of words to consider for the wordcloud
"""
num_words = 20

"""
set the resolution for the images (in dots per inch)
"""
dpi = 300

# %%
word_weights_file = join(wdir, model_folder, word_weights + ".txt")

wordles_out = join(wdir, out_folder, param_settings, "wordles")
#font_path = join(wdir, "font", "AlegreyaSans-Regular.otf")

num_topics = NumTopics
TopicRanksFile = join(wdir, aggregates_folder, param_settings, "topicRanks.csv")

# %%
visualize_verona.make_wordle_from_mallet(word_weights_file, NumTopics, num_words, TopicRanksFile, wordles_out, dpi)
# Out:
# Launched make_wordle_from_mallet.
# Done.

# %% [markdown]
# ## plot words-in-topics treemap

# %%
"""
set the number of words to plot
"""
words_to_plot = 10

# %%
word_weights_file = join(wdir, model_folder, word_weights + ".txt")
wordsintopics_treemap_out = join(out_dir, param_settings, "wordsintopics_treemap")

visualize_verona.plot_words_in_topics_treemap(NumTopics, words_to_plot, word_weights_file, wordsintopics_treemap_out)
# Out:
# Launched plot_words_in_topics_treemap.
# Done.

# %% [markdown]
# ## plot topics-in-docs treemap

# %%
"""
set the number of topics to plot
"""
topics_to_plot = 10

# %%
doc_topic_file = join(wdir, aggregates_folder, param_settings, "avgtopicscores_by-idno.csv")
first_words_file = join(wdir, aggregates_folder, param_settings, "firstWords.csv")
topicsindocs_treemap_out = join(out_dir, param_settings, "topicsindocs_treemap")

visualize_verona.plot_topics_in_docs_treemap(topics_to_plot, doc_topic_file, first_words_file, topicsindocs_treemap_out)
# Out:
# Launched plot_topics_in_docs_treemap.
# Done.

# %% [markdown]
# ## plot_topTopics

# %%
"""
creates a bar chart of the top topics for each metadata category
"""

"""
set the metadata categories which should be used (currently does not work for "publication-year")
"""
target = ["idno", "author-name", "author-gender", "title"]

"""
set the number of top topics to be shown
"""
topTopicsShown = 10

"""
set the font size for the charts
"""
fontscale = 1.0

"""
set the resolution for the images (in dots per inch)
"""
dpi = 300

"""
set the mode to "normalized" topic scores or "absolute" topic scores
"""
mode = "normalized"

# %%
averageDatasets = join(wdir, aggregates_folder, param_settings, "avg*.csv") 
firstWordsFile = join(wdir, aggregates_folder, param_settings, "firstWords.csv")
height = 0 # 0=automatic and variable
topTopics_out = join(wdir, out_folder, param_settings, "topTopics")

# %%
visualize_verona.plot_topTopics(averageDatasets, firstWordsFile, NumTopics, target, mode, topTopicsShown, fontscale, height, dpi, topTopics_out)
# Out:
# Launched plot_topTopics.
#  Getting targetItems for: author-name
# (30, 33)
# 30
#   Creating plot for: Barclay_Florence_L
# (30, 33)
# 30
#   Creating plot for: Bennet_Arnold
# (30, 33)
# 30
#   Creating plot for: Blackmore_R_D
# (30, 33)
# 30
#   Creating plot for: Braddon_Mary_Elizabeth
# (30, 33)
# 30
#   Creating plot for: Bronte_Charlotte
# (30, 33)
# 30
#   Creating plot for: Bulwer_Lytton_Edward
# (30, 33)
# 30
#   Creating plot for: Burnett_Frances_Hodgson
# (30, 33)
# 30
#   Creating plot for: Chesterton_G_K
# (30, 33)
# 30
#   Creating plot for: Collins_Wilkie
# (30, 33)
# 30
#   Creating plot for: Conrad_Joseph
# (30, 33)
# 30
#   Creating plot for: Corelli_Marie
# (30, 33)
# 30
#   Creating plot for: Dickens_Charles
# (30, 33)
# 30
#   Creating plot for: Doyle_Arthur_Conan
# (30, 33)
# 30
#   Creating plot for: Eliot_George
# (30, 33)
# 30
#   Creating plot for: Ford_Madox_Ford
# (30, 33)
# 30
#   Creating plot for: Forster_E_M
# (30, 33)
# 30
#   Creating plot for: Galsworthy_John
# (30, 33)
# 30
#   Creating plot for: Gaskell_Elizabeth
# (30, 33)
# 30
#   Creating plot for: Gissing_George
# (30, 33)
# 30
#   Creating plot for: Haggard_H_Rider
# (30, 33)
# 30
#   Creating plot for: Hardy_Thomas
# (30, 33)
# 30
#   Creating plot for: James_Henry
# (30, 33)
# 30
#   Creating plot for: Kipling_Rudyard
# (30, 33)
# 30
#   Creating plot for: Lawrence_D_H
# (30, 33)
# 30
#   Creating plot for: Lee_Vernon
# (30, 33)
# 30
#   Creating plot for: Meredith_George
# (30, 33)
# 30
#   Creating plot for: Morris_William
# (30, 33)
# 30
#   Creating plot for: Schreiner_Olive
# (30, 33)
# 30
#   Creating plot for: Stevenson_Robert_Louis
# (30, 33)
# 30
#   Creating plot for: Thackeray_William_Makepeace
# (30, 33)
# 30
#   Creating plot for: Trollope_Anthony
# (30, 33)
# 30
#   Creating plot for: Ward_Mary_Augusta
# (30, 33)
# 30
#   Creating plot for: Woolf_Virginia
#  Getting targetItems for: author-gender
# (30, 2)
# 30
#   Creating plot for: female
# (30, 2)
# 30
#   Creating plot for: male
#  Getting targetItems for: idno
# (30, 100)
# 30
#   Creating plot for: en0001
# (30, 100)
# 30
#   Creating plot for: en0002
# (30, 100)
# 30
#   Creating plot for: en0003
# (30, 100)
# 30
#   Creating plot for: en0004
# (30, 100)
# 30
#   Creating plot for: en0005
# (30, 100)
# 30
#   Creating plot for: en0006
# (30, 100)
# 30
#   Creating plot for: en0007
# (30, 100)
# 30
#   Creating plot for: en0008
# (30, 100)
# 30
#   Creating plot for: en0009
# (30, 100)
# 30
#   Creating plot for: en0010
# (30, 100)
# 30
#   Creating plot for: en0011
# (30, 100)
# 30
#   Creating plot for: en0012
# (30, 100)
# 30
#   Creating plot for: en0013
# (30, 100)
# 30
#   Creating plot for: en0014
# (30, 100)
# 30
#   Creating plot for: en0015
# (30, 100)
# 30
#   Creating plot for: en0016
# (30, 100)
# 30
#   Creating plot for: en0017
# (30, 100)
# 30
#   Creating plot for: en0018
# (30, 100)
# 30
#   Creating plot for: en0019
# (30, 100)
# 30
#   Creating plot for: en0020
# (30, 100)
# 30
#   Creating plot for: en0021
# (30, 100)
# 30
#   Creating plot for: en0022
# (30, 100)
# 30
#   Creating plot for: en0023
# (30, 100)
# 30
#   Creating plot for: en0024
# (30, 100)
# 30
#   Creating plot for: en0025
# (30, 100)
# 30
#   Creating plot for: en0026
# (30, 100)
# 30
#   Creating plot for: en0027
# (30, 100)
# 30
#   Creating plot for: en0028
# (30, 100)
# 30
#   Creating plot for: en0029
# (30, 100)
# 30
#   Creating plot for: en0030
# (30, 100)
# 30
#   Creating plot for: en0031
# (30, 100)
# 30
#   Creating plot for: en0032
# (30, 100)
# 30
#   Creating plot for: en0033
# (30, 100)
# 30
#   Creating plot for: en0034
# (30, 100)
# 30
#   Creating plot for: en0035
# (30, 100)
# 30
#   Creating plot for: en0036
# (30, 100)
# 30
#   Creating plot for: en0037
# (30, 100)
# 30
#   Creating plot for: en0038
# (30, 100)
# 30
#   Creating plot for: en0039
# (30, 100)
# 30
#   Creating plot for: en0040
# (30, 100)
# 30
#   Creating plot for: en0041
# (30, 100)
# 30
#   Creating plot for: en0042
# (30, 100)
# 30
#   Creating plot for: en0043
# (30, 100)
# 30
#   Creating plot for: en0044
# (30, 100)
# 30
#   Creating plot for: en0045
# (30, 100)
# 30
#   Creating plot for: en0046
# (30, 100)
# 30
#   Creating plot for: en0047
# (30, 100)
# 30
#   Creating plot for: en0048
# (30, 100)
# 30
#   Creating plot for: en0049
# (30, 100)
# 30
#   Creating plot for: en0050
# (30, 100)
# 30
#   Creating plot for: en0051
# (30, 100)
# 30
#   Creating plot for: en0052
# (30, 100)
# 30
#   Creating plot for: en0053
# (30, 100)
# 30
#   Creating plot for: en0054
# (30, 100)
# 30
#   Creating plot for: en0055
# (30, 100)
# 30
#   Creating plot for: en0056
# (30, 100)
# 30
#   Creating plot for: en0057
# (30, 100)
# 30
#   Creating plot for: en0058
# (30, 100)
# 30
#   Creating plot for: en0059
# (30, 100)
# 30
#   Creating plot for: en0060
# (30, 100)
# 30
#   Creating plot for: en0061
# (30, 100)
# 30
#   Creating plot for: en0062
# (30, 100)
# 30
#   Creating plot for: en0063
# (30, 100)
# 30
#   Creating plot for: en0064
# (30, 100)
# 30
#   Creating plot for: en0065
# (30, 100)
# 30
#   Creating plot for: en0066
# (30, 100)
# 30
#   Creating plot for: en0067
# (30, 100)
# 30
#   Creating plot for: en0068
# (30, 100)
# 30
#   Creating plot for: en0069
# (30, 100)
# 30
#   Creating plot for: en0070
# (30, 100)
# 30
#   Creating plot for: en0071
# (30, 100)
# 30
#   Creating plot for: en0072
# (30, 100)
# 30
#   Creating plot for: en0073
# (30, 100)
# 30
#   Creating plot for: en0074
# (30, 100)
# 30
#   Creating plot for: en0075
# (30, 100)
# 30
#   Creating plot for: en0076
# (30, 100)
# 30
#   Creating plot for: en0077
# (30, 100)
# 30
#   Creating plot for: en0078
# (30, 100)
# 30
#   Creating plot for: en0079
# (30, 100)
# 30
#   Creating plot for: en0080
# (30, 100)
# 30
#   Creating plot for: en0081
# (30, 100)
# 30
#   Creating plot for: en0082
# (30, 100)
# 30
#   Creating plot for: en0083
# (30, 100)
# 30
#   Creating plot for: en0084
# (30, 100)
# 30
#   Creating plot for: en0085
# (30, 100)
# 30
#   Creating plot for: en0086
# (30, 100)
# 30
#   Creating plot for: en0087
# (30, 100)
# 30
#   Creating plot for: en0088
# (30, 100)
# 30
#   Creating plot for: en0089
# (30, 100)
# 30
#   Creating plot for: en0090
# (30, 100)
# 30
#   Creating plot for: en0091
# (30, 100)
# 30
#   Creating plot for: en0092
# (30, 100)
# 30
#   Creating plot for: en0093
# (30, 100)
# 30
#   Creating plot for: en0094
# (30, 100)
# 30
#   Creating plot for: en0095
# (30, 100)
# 30
#   Creating plot for: en0096
# (30, 100)
# 30
#   Creating plot for: en0097
# (30, 100)
# 30
#   Creating plot for: en0098
# (30, 100)
# 30
#   Creating plot for: en0099
# (30, 100)
# 30
#   Creating plot for: en0100
#  Getting targetItems for: title
# (30, 100)
# 30
#   Creating plot for: A Little Princess
# (30, 100)
# 30
#   Creating plot for: A Romance of Two Worlds
# (30, 100)
# 30
#   Creating plot for: A Room with a View
# (30, 100)
# 30
#   Creating plot for: Adam Brede
# (30, 100)
# 30
#   Creating plot for: Almayer‘s Folly
# (30, 100)
# 30
#   Creating plot for: An English Girl
# (30, 100)
# 30
#   Creating plot for: Ayala‘s Angel
# (30, 100)
# 30
#   Creating plot for: Basil
# (30, 100)
# 30
#   Creating plot for: Bleak House
# (30, 100)
# 30
#   Creating plot for: Captains Courageous
# (30, 100)
# 30
#   Creating plot for: Catriona
# (30, 100)
# 30
#   Creating plot for: Clara Vaughan
# (30, 100)
# 30
#   Creating plot for: Daniel Deronda
# (30, 100)
# 30
#   Creating plot for: Erema
# (30, 100)
# 30
#   Creating plot for: Far from the Madding Crowd
# (30, 100)
# 30
#   Creating plot for: Felix Holt, the Radical
# (30, 100)
# 30
#   Creating plot for: Fenton‘s Quest
# (30, 100)
# 30
#   Creating plot for: Great Expectations
# (30, 100)
# 30
#   Creating plot for: Harvest
# (30, 100)
# 30
#   Creating plot for: Helen with a High Hand
# (30, 100)
# 30
#   Creating plot for: Howards End
# (30, 100)
# 30
#   Creating plot for: Imperial Palace
# (30, 100)
# 30
#   Creating plot for: Innocent
# (30, 100)
# 30
#   Creating plot for: Jane Eyre
# (30, 100)
# 30
#   Creating plot for: Jude the Obscure
# (30, 100)
# 30
#   Creating plot for: Kenelm Chillingly
# (30, 100)
# 30
#   Creating plot for: Kim
# (30, 100)
# 30
#   Creating plot for: King Solomon‘s Mines
# (30, 100)
# 30
#   Creating plot for: Lady Audley‘s Secret
# (30, 100)
# 30
#   Creating plot for: Last Post
# (30, 100)
# 30
#   Creating plot for: Little Lord Fauntleroy
# (30, 100)
# 30
#   Creating plot for: Lorna Doone
# (30, 100)
# 30
#   Creating plot for: Micah Clarke
# (30, 100)
# 30
#   Creating plot for: Milly and Olly
# (30, 100)
# 30
#   Creating plot for: Miss Brown
# (30, 100)
# 30
#   Creating plot for: My Novel
# (30, 100)
# 30
#   Creating plot for: Night and Day
# (30, 100)
# 30
#   Creating plot for: Nostromo
# (30, 100)
# 30
#   Creating plot for: One More River
# (30, 100)
# 30
#   Creating plot for: Pendennis
# (30, 100)
# 30
#   Creating plot for: Penelope Brandling
# (30, 100)
# 30
#   Creating plot for: Phantom Fortune
# (30, 100)
# 30
#   Creating plot for: Phineas Finn
# (30, 100)
# 30
#   Creating plot for: Roderick Hudson
# (30, 100)
# 30
#   Creating plot for: Ruth
# (30, 100)
# 30
#   Creating plot for: Saint‘s Progress
# (30, 100)
# 30
#   Creating plot for: She
# (30, 100)
# 30
#   Creating plot for: She and Allan
# (30, 100)
# 30
#   Creating plot for: Shirley
# (30, 100)
# 30
#   Creating plot for: Springhaven
# (30, 100)
# 30
#   Creating plot for: Sylvia‘s Lovers
# (30, 100)
# 30
#   Creating plot for: Tess of the d‘Urbervilles
# (30, 100)
# 30
#   Creating plot for: The Adventures of Harry Richmond
# (30, 100)
# 30
#   Creating plot for: The Adventures of Oliver Twist
# (30, 100)
# 30
#   Creating plot for: The Amazing Marriage
# (30, 100)
# 30
#   Creating plot for: The Ambassadors
# (30, 100)
# 30
#   Creating plot for: The Black Arrow
# (30, 100)
# 30
#   Creating plot for: The Countess of Albany
# (30, 100)
# 30
#   Creating plot for: The Good Soldier
# (30, 100)
# 30
#   Creating plot for: The Grand Babylon Hotel
# (30, 100)
# 30
#   Creating plot for: The History of Henry Esmond
# (30, 100)
# 30
#   Creating plot for: The Hound of the Baskervilles
# (30, 100)
# 30
#   Creating plot for: The Innocence of Father Brown
# (30, 100)
# 30
#   Creating plot for: The Legacy of Cain
# (30, 100)
# 30
#   Creating plot for: The Light that Failed
# (30, 100)
# 30
#   Creating plot for: The Lost World
# (30, 100)
# 30
#   Creating plot for: The Man Who Was Thursday
# (30, 100)
# 30
#   Creating plot for: The Man of Property
# (30, 100)
# 30
#   Creating plot for: The Marriage of William Ashe
# (30, 100)
# 30
#   Creating plot for: The Napoleon of Notting Hill
# (30, 100)
# 30
#   Creating plot for: The Odd Women
# (30, 100)
# 30
#   Creating plot for: The Ordeal of Richard Feverel
# (30, 100)
# 30
#   Creating plot for: The Plumed Serpent
# (30, 100)
# 30
#   Creating plot for: The Roots of the Mountains
# (30, 100)
# 30
#   Creating plot for: The Rosary
# (30, 100)
# 30
#   Creating plot for: The Rover
# (30, 100)
# 30
#   Creating plot for: The Secret Garden
# (30, 100)
# 30
#   Creating plot for: The Sorrows of Satan
# (30, 100)
# 30
#   Creating plot for: The Tragic Muse
# (30, 100)
# 30
#   Creating plot for: The Unclassed
# (30, 100)
# 30
#   Creating plot for: The Virginians
# (30, 100)
# 30
#   Creating plot for: The Warden
# (30, 100)
# 30
#   Creating plot for: The Water of the Wondrous Isles
# (30, 100)
# 30
#   Creating plot for: The White Ladies of Worcester
# (30, 100)
# 30
#   Creating plot for: The White Peacock
# (30, 100)
# 30
#   Creating plot for: The Woman in White
# (30, 100)
# 30
#   Creating plot for: The Wood Beyond the World
# (30, 100)
# 30
#   Creating plot for: The Years
# (30, 100)
# 30
#   Creating plot for: The story of an African Farm
# (30, 100)
# 30
#   Creating plot for: Through the Postern Gate
# (30, 100)
# 30
#   Creating plot for: To the Lighthouse
# (30, 100)
# 30
#   Creating plot for: Treasure Island
# (30, 100)
# 30
#   Creating plot for: Trooper Peter Halket of Mashonaland
# (30, 100)
# 30
#   Creating plot for: Undine
# (30, 100)
# 30
#   Creating plot for: Villette
# (30, 100)
# 30
#   Creating plot for: What will he do with it?
# (30, 100)
# 30
#   Creating plot for: Where Angels Fear to Tread
# (30, 100)
# 30
#   Creating plot for: Will Warburton
# (30, 100)
# 30
#   Creating plot for: Wives and Daughters
# (30, 100)
# 30
#   Creating plot for: Women in Love
# Done.

# %% [markdown]
# ## plot_topItems

# %%
"""
creates a barchart for each topic, with the top items (titles, authors, etc.) for that topic
"""

"""
set the metadata categories to plot
"""
target = ["idno", "author-name", "author-gender", "title", "publication-year"]

"""
set the number of top items to show
"""
topItemsShown = 20

"""
set the font size
"""
fontscale = 0.8

"""
set the resolution of the images (in dots per inch)
"""
dpi = 300

# %%
averageDatasets = join(wdir, aggregates_folder, param_settings, "avg*.csv")
topItems_out = join(wdir, out_folder, param_settings, "topItems")
firstWordsFile = join(wdir, aggregates_folder, param_settings, "firstWords.csv")
height = 0 # 0=automatic and flexible

# %%
visualize_verona.plot_topItems(averageDatasets, topItems_out, firstWordsFile, NumTopics, target, topItemsShown, fontscale, height, dpi)
# Out:
# Launched plot_topItems
#  Plotting for: author-name
#   Creating plot for topic: 0
# /home/ulrike/Git/tmw/scripts_verona/visualize_verona.py:241: FutureWarning: order is deprecated, use sort_values(...)
#   dataToPlot = dataToPlot.order(ascending=False)
#   Creating plot for topic: 1
#   Creating plot for topic: 2
#   Creating plot for topic: 3
#   Creating plot for topic: 4
#   Creating plot for topic: 5
#   Creating plot for topic: 6
#   Creating plot for topic: 7
#   Creating plot for topic: 8
#   Creating plot for topic: 9
#   Creating plot for topic: 10
#   Creating plot for topic: 11
#   Creating plot for topic: 12
#   Creating plot for topic: 13
#   Creating plot for topic: 14
#   Creating plot for topic: 15
#   Creating plot for topic: 16
#   Creating plot for topic: 17
#   Creating plot for topic: 18
#   Creating plot for topic: 19
#   Creating plot for topic: 20
#   Creating plot for topic: 21
#   Creating plot for topic: 22
#   Creating plot for topic: 23
#   Creating plot for topic: 24
#   Creating plot for topic: 25
#   Creating plot for topic: 26
#   Creating plot for topic: 27
#   Creating plot for topic: 28
#   Creating plot for topic: 29
#  Plotting for: author-gender
#   Creating plot for topic: 0
#   Creating plot for topic: 1
#   Creating plot for topic: 2
#   Creating plot for topic: 3
#   Creating plot for topic: 4
#   Creating plot for topic: 5
#   Creating plot for topic: 6
#   Creating plot for topic: 7
#   Creating plot for topic: 8
#   Creating plot for topic: 9
#   Creating plot for topic: 10
#   Creating plot for topic: 11
#   Creating plot for topic: 12
#   Creating plot for topic: 13
#   Creating plot for topic: 14
#   Creating plot for topic: 15
#   Creating plot for topic: 16
#   Creating plot for topic: 17
#   Creating plot for topic: 18
#   Creating plot for topic: 19
#   Creating plot for topic: 20
#   Creating plot for topic: 21
#   Creating plot for topic: 22
#   Creating plot for topic: 23
#   Creating plot for topic: 24
#   Creating plot for topic: 25
#   Creating plot for topic: 26
#   Creating plot for topic: 27
#   Creating plot for topic: 28
#   Creating plot for topic: 29
#  Plotting for: publication-year
#   Creating plot for topic: 0
#   Creating plot for topic: 1
#   Creating plot for topic: 2
#   Creating plot for topic: 3
#   Creating plot for topic: 4
#   Creating plot for topic: 5
#   Creating plot for topic: 6
#   Creating plot for topic: 7
#   Creating plot for topic: 8
#   Creating plot for topic: 9
#   Creating plot for topic: 10
#   Creating plot for topic: 11
#   Creating plot for topic: 12
#   Creating plot for topic: 13
#   Creating plot for topic: 14
#   Creating plot for topic: 15
#   Creating plot for topic: 16
#   Creating plot for topic: 17
#   Creating plot for topic: 18
#   Creating plot for topic: 19
#   Creating plot for topic: 20
#   Creating plot for topic: 21
#   Creating plot for topic: 22
#   Creating plot for topic: 23
#   Creating plot for topic: 24
#   Creating plot for topic: 25
#   Creating plot for topic: 26
#   Creating plot for topic: 27
#   Creating plot for topic: 28
#   Creating plot for topic: 29
#  Plotting for: idno
#   Creating plot for topic: 0
#   Creating plot for topic: 1
#   Creating plot for topic: 2
#   Creating plot for topic: 3
#   Creating plot for topic: 4
#   Creating plot for topic: 5
#   Creating plot for topic: 6
#   Creating plot for topic: 7
#   Creating plot for topic: 8
#   Creating plot for topic: 9
#   Creating plot for topic: 10
#   Creating plot for topic: 11
#   Creating plot for topic: 12
#   Creating plot for topic: 13
#   Creating plot for topic: 14
#   Creating plot for topic: 15
#   Creating plot for topic: 16
#   Creating plot for topic: 17
#   Creating plot for topic: 18
#   Creating plot for topic: 19
#   Creating plot for topic: 20
#   Creating plot for topic: 21
#   Creating plot for topic: 22
#   Creating plot for topic: 23
#   Creating plot for topic: 24
#   Creating plot for topic: 25
#   Creating plot for topic: 26
#   Creating plot for topic: 27
#   Creating plot for topic: 28
#   Creating plot for topic: 29
#  Plotting for: title
#   Creating plot for topic: 0
#   Creating plot for topic: 1
#   Creating plot for topic: 2
#   Creating plot for topic: 3
#   Creating plot for topic: 4
#   Creating plot for topic: 5
#   Creating plot for topic: 6
#   Creating plot for topic: 7
#   Creating plot for topic: 8
#   Creating plot for topic: 9
#   Creating plot for topic: 10
#   Creating plot for topic: 11
#   Creating plot for topic: 12
#   Creating plot for topic: 13
#   Creating plot for topic: 14
#   Creating plot for topic: 15
#   Creating plot for topic: 16
#   Creating plot for topic: 17
#   Creating plot for topic: 18
#   Creating plot for topic: 19
#   Creating plot for topic: 20
#   Creating plot for topic: 21
#   Creating plot for topic: 22
#   Creating plot for topic: 23
#   Creating plot for topic: 24
#   Creating plot for topic: 25
#   Creating plot for topic: 26
#   Creating plot for topic: 27
#   Creating plot for topic: 28
#   Creating plot for topic: 29
# Done.

# %% [markdown]
# ## plot_distinctiveness_heatmap

# %%
"""
for each category, make a heatmap of most distinctive topics
"""

"""
set the target metadata categories to use for the heatmap
"""
target = ["author-name", "author-gender", "title"]

"""
set the top topics shown
"""
topTopicsShown = 20

"""
set the mode for normalization of the heatmap values
possible values: meannorm|mediannorm|zscores|absolute
"""
mode = "zscores"

"""
set the font scale
"""
fontscale = 1.0

"""
set the resolution for the images
"""
dpi = 300

# %%
averageDatasets = join(wdir, aggregates_folder, param_settings, "avg*.csv") 
firstWordsFile = join(wdir, aggregates_folder, param_settings, "firstWords.csv")
out_distinctiveness = join(wdir, out_folder, param_settings, "distinctiveness")
sorting = "std"

# %%
visualize_verona.plot_distinctiveness_heatmap(averageDatasets, firstWordsFile, out_distinctiveness, target, NumTopics, topTopicsShown, mode, sorting, fontscale, dpi)
# Out:
# Launched plot_distinctiveness_heatmap.
# - working on: author-name
# - getting dataToPlot...
# - working on: author-gender
# - getting dataToPlot...
# - working on: title
# - getting dataToPlot...
# Done.
